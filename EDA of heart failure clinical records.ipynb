# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

# %%
pwd
# Out:
# 'C:\\Users\\Asus\\Downloads'

# %%
data = pd.read_excel("heart_failure_clinical_records.xlsx")

# %%
data.head()
# Out:
#    Age  Creatinine Phosphokinase  High Blood Pressure  Platelets  Smoking  \
# 0   75                       582                    1  265000.00        0
# 1   55                      7861                    0  263358.03        0
# 2   65                       146                    0  162000.00        1
# 3   50                       111                    0  210000.00        0
# 4   65                       160                    0  327000.00        0
#
#    DEATH EVENT
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
data.tail()
# Out:
#     Age  Creatinine Phosphokinase  High Blood Pressure  Platelets  Smoking  \
# 95   58                       133                    1   219000.0        0
# 96   63                       514                    1   254000.0        0
# 97   70                        59                    0   255000.0        0
# 98   60                       156                    1   318000.0        0
# 99   63                        61                    0   221000.0        0
#
#     DEATH EVENT
# 95            0
# 96            0
# 97            0
# 98            0
# 99            0

# %%
data.columns
# Out:
# Index(['Age', 'Creatinine Phosphokinase', 'High Blood Pressure', 'Platelets',
#        'Smoking', 'DEATH EVENT'],
#       dtype='object')

# %%
data.describe()
# Out:
#               Age  Creatinine Phosphokinase  High Blood Pressure  \
# count  100.000000                100.000000               100.00
# mean    63.660000                549.560000                 0.45
# std     12.908552               1280.217274                 0.50
# min     41.000000                 23.000000                 0.00
# 25%     55.000000                 93.500000                 0.00
# 50%     62.500000                159.500000                 0.00
# 75%     70.000000                582.000000                 1.00
# max     95.000000               7861.000000                 1.00
#
#            Platelets     Smoking  DEATH EVENT
# count     100.000000  100.000000   100.000000
# mean   262592.222700    0.330000     0.660000
# std     85943.987246    0.472582     0.476095
# min     47000.000000    0.000000     0.000000
# 25%    208500.000000    0.000000     0.000000
# 50%    263358.030000    0.000000     1.000000
# 75%    311750.000000    1.000000     1.000000
# ...

# %%
data.nunique()
# Out:
# Age                         31
# Creatinine Phosphokinase    80
# High Blood Pressure          2
# Platelets                   75
# Smoking                      2
# DEATH EVENT                  2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Age                         0
# Creatinine Phosphokinase    0
# High Blood Pressure         0
# Platelets                   0
# Smoking                     0
# DEATH EVENT                 0
# dtype: int64

# %%
CP = data['Creatinine Phosphokinase']

# %%
mean = np.mean(CP)

# %%
print(mean)
# Out:
# 549.56

# %%
median = np.median(CP)

# %%
print(median)
# Out:
# 159.5

# %%
mode = stats.mode(CP)

# %%
mode
# Out:
# ModeResult(mode=array([582], dtype=int64), count=array([15]))

# %%
corelation = data.corr()

# %%
sns.heatmap(corelation,xticklabels = corelation.columns, yticklabels = corelation.columns,annot =True)

# %%
sns.pairplot(data)

# %%
sns.barplot(x='Smoking', y= 'DEATH EVENT',data = data)

# %%
sns.distplot(data['Smoking'])

# %%
data.shape
# Out:
# (100, 6)

# %%
sns.relplot(x='Platelets', y= 'Age',hue = 'Smoking',data = data)

# %%
sns.barplot(x='Smoking', y= 'Platelets',data = data)

# %%
sns.barplot(x='Smoking', y= 'High Blood Pressure',data = data)

# %%
sns.barplot(x='DEATH EVENT', y= 'Platelets',data = data)

# %%
sns.relplot(x='Age', y= 'Creatinine Phosphokinase',hue = 'Smoking',data = data)

# %%
sns.barplot(x='Smoking', y= 'Age',data = data)
