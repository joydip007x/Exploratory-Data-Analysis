# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats

# %%
data = pd.read_excel("academic_and_employability_factors_influencing_placement.xlsx")

# %%
data.head()
# Out:
#   Gender  Degree Performance Degree Type  MBA Performance Placement Status  \
# 0      M               58.00    Sci&Tech            58.80           Placed
# 1      M               77.48    Sci&Tech            66.28           Placed
# 2      M               64.00   Comm&Mgmt            57.80           Placed
# 3      M               52.00    Sci&Tech            59.43       Not Placed
# 4      M               73.30   Comm&Mgmt            55.50           Placed
#
#      Salary
# 0  270000.0
# 1  200000.0
# 2  250000.0
# 3       NaN
# 4  425000.0

# %%
data.shape
# Out:
# (100, 6)

# %%
data.columns
# Out:
# Index(['Gender', 'Degree Performance', 'Degree Type', 'MBA Performance',
#        'Placement Status', 'Salary'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Gender                 2
# Degree Performance    55
# Degree Type            3
# MBA Performance       98
# Placement Status       2
# Salary                31
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Gender                 0
# Degree Performance     0
# Degree Type            0
# MBA Performance        0
# Placement Status       0
# Salary                31
# dtype: int64

# %%
data.describe()
# Out:
#        Degree Performance  MBA Performance         Salary
# count          100.000000       100.000000      69.000000
# mean            66.940100        62.146600  279898.550725
# std              7.471361         5.651187   65811.483203
# min             50.000000        51.210000  200000.000000
# 25%             64.000000        57.772500  240000.000000
# 50%             66.000000        62.410000  265000.000000
# 75%             72.000000        66.342500  300000.000000
# max             85.000000        77.890000  500000.000000

# %%
MBA_Performance = data['MBA Performance']

# %%
mean_of_MBA_Performance = np.mean(MBA_Performance)
mean_of_MBA_Performance
# Out:
# 62.146599999999964

# %%
median_of_MBA_Performance= np.median(MBA_Performance)
median_of_MBA_Performance
# Out:
# 62.41

# %%
mode_of_MBA_Performance = stats.mode(MBA_Performance)
mode_of_MBA_Performance
# Out:
# ModeResult(mode=array([56.7]), count=array([2]))

# %%
Degree_Performance = data['Degree Performance']

# %%
mean_of_Degree_Performance =np.mean(Degree_Performance)
mean_of_Degree_Performance
# Out:
# 66.9401

# %%
median_of_Degree_Performance = np.median(Degree_Performance)
median_of_Degree_Performance
# Out:
# 66.0

# %%
mode_of_Degree_Performance = stats.mode(Degree_Performance)
mode_of_Degree_Performance
# Out:
# ModeResult(mode=array([66.]), count=array([9]))

# %%
salary = data['Salary']

# %%
mean_of_salary = np.mean(salary)
mean_of_salary
# Out:
# 279898.5507246375

# %%
median_of_salary = np.median(salary)
median_of_salary
# Out:
# nan

# %%
mode_of_salary = stats.mode(salary)
mode_of_salary
# Out:
# ModeResult(mode=array([300000.]), count=array([10]))

# %% [markdown]
# Now we will fill the null values with the average values.
# We notice that the the group of people who are not placed, their salary is Not Available. So we can take their salary is 0( zero ).

# %%
data['Salary'].fillna(value=0, inplace=True)

# %%
data.isnull().sum()
# Out:
# Gender                0
# Degree Performance    0
# Degree Type           0
# MBA Performance       0
# Placement Status      0
# Salary                0
# dtype: int64

# %%
median_of_salary = np.median(salary)
median_of_salary
# Out:
# 279898.5507246377

# %%
sns.distplot(data['Salary'])

# %%
sns.distplot(data['Degree Performance'])

# %%
sns.distplot(data['MBA Performance'])

# %%
sns.relplot(x = 'Degree Performance', y = 'MBA Performance',hue = 'Gender', data = data)

# %%
sns.relplot(x = 'Degree Performance', y = 'MBA Performance',hue = 'Placement Status', data = data)

# %%
sns.relplot(x = 'Degree Performance', y = 'Salary',hue = 'Gender', data = data)

# %%
sns.relplot(x = 'MBA Performance', y = 'Salary',hue = 'Gender', data = data)

# %%
sns.pairplot(data)

# %%
corelation = data.corr()
sns.heatmap(corelation, xticklabels = corelation.columns, yticklabels = corelation.columns, annot = True)
