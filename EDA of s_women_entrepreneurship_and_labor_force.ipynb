# %% [markdown]
# # EDA ( Exploratory Data Analysis )
# In this Interactive Python Notebook, we will analyze our dataset.

# %% [markdown]
# # Roman Raihan
#
# # 2017331088
#
# ## session : 2017-18

# %% [markdown]
# To start analysis, we have to learn about our dataset as much as possible. So, at first, we import some python librarries which will be used to analyze the data. And then we load our data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel("s_women_entrepreneurship_and_labor_force.xlsx")

# %% [markdown]
# Data loading is completed.
#
# Now let's have a look on the first 5 rows of our data.

# %%
data.head(5)
# Out:
#    Country Level of Development  Women Entrepreneurship Index  \
# 0  Austria            Developed                          54.9
# 1  Belgium            Developed                          63.6
# 2  Estonia            Developed                          55.4
# 3  Finland            Developed                          66.4
# 4   France            Developed                          68.8
#
#    Entrepreneurship Index  Female Labor Force Participation Rate
# 0                    64.9                                   67.1
# 1                    65.5                                   58.0
# 2                    60.2                                   68.5
# 3                    65.7                                   67.7
# 4                    67.3                                   60.6

# %% [markdown]
# There is a country name, Level of Development of that country, Womnen Entrepreneurship Index , Entrepreneurship Index and Female Labor Force Participation Rate of that country in each row.
# So the dataset is about the the impact of Womnen Entrepreneurship Index , Entrepreneurship Index and Female Labor Force Participation Rate on the development of a country. The main features are:
#
# 1. Womnen Entrepreneurship Index
# 2. Entrepreneurship Index and
# 3. Female Labor Force Participation Rate
#
# These three features are decimal point numbers. So data type is floating point number.

# %%
data.shape
# Out:
# (51, 5)

# %%
data.isnull().sum()
# Out:
# Country                                  0
# Level of Development                     0
# Women Entrepreneurship Index             0
# Entrepreneurship Index                   0
# Female Labor Force Participation Rate    0
# dtype: int64

# %% [markdown]
# The Dataset hasn't any  missing value. It has 51 rows and 5 columns.

# %%
data.describe()
# Out:
#        Women Entrepreneurship Index  Entrepreneurship Index  \
# count                     51.000000               51.000000
# mean                      47.835294               47.241176
# std                       14.268480               16.193149
# min                       25.300000               24.800000
# 25%                       36.350000               31.900000
# 50%                       44.500000               42.700000
# 75%                       59.150000               65.400000
# max                       74.800000               77.600000
#
#        Female Labor Force Participation Rate
# count                              51.000000
# mean                               58.481765
# std                                13.864567
# min                                13.000000
# 25%                                55.800000
# 50%                                61.000000
# 75%                                67.400000
# max                                82.300000

# %%
data.columns
# Out:
# Index(['Country', 'Level of Development', 'Women Entrepreneurship Index',
#        'Entrepreneurship Index', 'Female Labor Force Participation Rate'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Country                                  51
# Level of Development                      2
# Women Entrepreneurship Index             50
# Entrepreneurship Index                   49
# Female Labor Force Participation Rate    48
# dtype: int64

# %%
data['Level of Development'].unique()
# Out:
# array(['Developed', 'Developing'], dtype=object)

# %%
corelation = data.corr()

# %%
sns.heatmap(corelation,xticklabels = corelation.columns, yticklabels = corelation.columns,annot =True)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='Women Entrepreneurship Index', y= 'Female Labor Force Participation Rate',hue='Level of Development',data = data)

# %%
sns.relplot(x = 'Women Entrepreneurship Index',y ='Entrepreneurship Index',hue = 'Level of Development',data = data)

# %%
sns.relplot(x = 'Entrepreneurship Index', y = 'Female Labor Force Participation Rate', hue = 'Level of Development',data =data)

# %%
sns.distplot(data['Female Labor Force Participation Rate'])

# %%
sns.distplot(data['Women Entrepreneurship Index'])

# %%
sns.distplot(data['Entrepreneurship Index'])
